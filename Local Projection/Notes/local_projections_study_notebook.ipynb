# %% [markdown]
# # Local Projections (LP) — Study Notebook
#
# This notebook organizes key conceptual questions about Local Projections (LP) in econometrics.
# Use it as a structured study and revision guide.

# %% [markdown]
# ## 🔹 A. Core Idea of LP
#
# **Q1. What is the key idea behind Local Projections (LP)?**
# How does it differ from VAR in constructing impulse responses?
#
# **Q2. Why does LP estimate a separate regression for each horizon $h$?**
# What advantage does this provide?

# %% [markdown]
# ## 🔹 B. Regression Specification
#
# **Q3. Write down the baseline LP regression.**
# Clearly define each term.
#
# **Q4. What is the role of:**
# - $x_t$?
# - $Z_t$?
#
# **Q5. Why do we include lags in $Z_t$?**
# What problem do they solve?

# %% [markdown]
# ## 🔹 C. Interpretation of Coefficients
#
# **Q6. What does $\beta_h$ represent?**
# Give both:
# - mathematical interpretation
# - economic interpretation
#
# **Q7. How do the units of $\beta_h$ depend on the variables?**
# Give an example.
#
# **Q8. Why does $\beta_h$ vary with $h$?**
# What does the sequence $\{\beta_h\}$ represent?

# %% [markdown]
# ## 🔹 D. Identification
#
# **Q9. Under what condition can $\beta_h$ be interpreted as a causal effect?**
# What must be true about $x_t$?
#
# **Q10. Does LP solve the identification problem?**
# Why or why not?

# %% [markdown]
# ## 🔹 E. Estimation & Inference
#
# **Q11. How do you estimate LP in practice?**
# List the steps.
#
# **Q12. Why are standard errors in LP non-trivial?**
# What issue arises across horizons?
#
# **Q13. What type of standard errors should be used?**
# Why?

# %% [markdown]
# ## 🔹 F. LP vs VAR
#
# **Q14. What are the main advantages of LP over VAR?**
#
# **Q15. What are the disadvantages of LP?**

# %% [markdown]
# ## 🔹 G. Extensions (State Dependence)
#
# **Q16. How does Jordà suggest extending LP to allow nonlinearities?**
# What kind of modification is needed?
#
# **Q17. How would you introduce a state variable $S_t$ into LP?**
# Write the modified regression.

# %% [markdown]
# ## 🔥 H. Deep Understanding Check
#
# **Q18. Suppose you redefine your shock:**
# from “1-unit shock” → “1 standard deviation shock”
# 👉 What happens to $\beta_h$?
#
# **Q19. If you omit important lags in $Z_t$, what happens to your estimates?**
#
# **Q20. Why is LP considered more robust to model misspecification than VAR?**
